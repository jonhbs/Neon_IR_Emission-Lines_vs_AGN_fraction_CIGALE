# %% [markdown]
# # Classification according the Ne II, Ne III and Ne V emission lines information - Download the Photometry Tables for each object found
#
# From the objects that we find in NED with Ne emission lines, now we are going to classify according to what information the Ne II, Ne III and Ne V emission lines each have.
#
# Also inside the main loop, for each object found in NED with Ne emission lines, we will save the photometry tables in a .csv file.

# %%
from datetime import date
import time
import pandas as pd
import numpy as np
import csv

import pyvo
from astroquery.ned import Ned

import astropy.units as u
from astropy.table import hstack

# %%
path = '../Datos/Raw/'
path2 = '../Datos/Phot_Tables/' #In this path wi will save the photometry tables for each object

# %%
today = date.today()

# %%
df = pd.read_csv(path+'Obj_Ne-IR_Oct_15_2021.csv')

# %% [markdown]
# The wavelenght for NeII, NeIII and NeV in the infrared spectrum are 12.8 microns, 15.6 microns and 14.3 microns respectively. This values are equivalents to the following frequencies which are related to different labels of "Observed Passband" in NED database as we ilustrate in the next list:
#
# * Frequency: 1.92e+13 Hz: [NeIII] 15.6 microns
# * Frecuency: 1.93e+13 Hz: [Ne III] 15.56 (IRS), [NeIII] 15.6 Spitzer, [Ne III] (Spitzer), [Ne III] 15.5 (IRS)
# * Frecuency: 2.09e+13 Hz: [Ne V] 14.32 (IRS), [Ne V] 14.32 Spitzer, [Ne V] 14.32, [Ne V] 14.3 Spitzer, [Ne V] 14.3 microns
# * Frequency: 2.10e+13 Hz: [Ne V] 14.3 (IRS)
# * Frequency: 2.34e+13 Hz: [Ne II] 12.81 (IRS), [Ne II] 12.8 Spitzer, [Ne II] 12.8 (IRS), [Ne II] 12.81, NEII (VLT), 12.81 microns (VLT)
#
# In the variable **Ne_IR_Fq** we define a list with the those frequency values

# %%
Ne_IR_Fq = [19200000000000.0,19300000000000.0,20900000000000.0,21000000000000.0,23400000000000.0]

# %%
NeII_NeIII_NeV_IR_obj = [] #List of objects with NeII, NeIII and NeV data
NeII_NeIII_IR_obj = [] #List of objects with NeII and NeIII data
NeII_NeV_IR_obj = [] #List of objects with NeII and NeV data
NeIII_NeV_IR_obj = [] #List of objects with NeIII and NeV data
NeIII_IR_obj = [] #List of objects with NeIII data
NeV_IR_obj = [] #List of objects with NeV data
NeII_IR_obj = [] #List of objects with NeII data

#We create and open a file .csv to write the list of objects names with Ne_IR data
outfile = open(path+'Obj_Ne-IR_v2_'+today.strftime('%b_%d_%Y')+'.csv','w')
writer = csv.writer(outfile) # create the csv writer
header = ['Name_Id','id_from','RA','DEC','otype_txt','redshift','rvz_type','otypes','Ne_IR_info','SMB_sample']#Creating header
writer.writerow(header) #Writing the header

start = time.time()
for ind, name in enumerate(df['Name_Id']):
    phot_t = Ned.get_table(name, table='photometry') #We get the Photometry Table using SIMBAD names
    
    phot_t.write(path2+name+'_'+today.strftime('%b_%d_%Y')+'_phot_tables'+'.csv',
                    format='ascii.csv',overwrite=True)
    
    Fr=phot_t['Frequency'] #We get the Frequency column from the table
   
    if (Ne_IR_Fq[0] in Fr or Ne_IR_Fq[1] in Fr) and (Ne_IR_Fq[2] in Fr or Ne_IR_Fq[3] in Fr) and Ne_IR_Fq[4] in Fr:
        print(f"{ind}, {name}, NeII, NeIII and NeV")
        #Writing the object names
        outstring = [name,df['id_from'][ind],df['RA'][ind],df['DEC'][ind],df['otype_txt'][ind],df['redshift'][ind],
                     df['rvz_type'][ind],df['otypes'][ind],'NeII|NeIII|NeV',df['SMB_sample'][ind]]
        writer.writerow(outstring) #write the data
        NeII_NeIII_NeV_IR_obj.append(name) #Save the object name in the list NeII_NeIII_NeV_IR_obj
    
    elif (Ne_IR_Fq[0] in Fr or Ne_IR_Fq[1] in Fr) and Ne_IR_Fq[4] in Fr:
        print(f"{ind}, {name}, NeII and NeIII")
        #Writing the object names
        outstring = [name,df['id_from'][ind],df['RA'][ind],df['DEC'][ind],df['otype_txt'][ind],df['redshift'][ind],
                     df['rvz_type'][ind],df['otypes'][ind],'NeII|NeIII',df['SMB_sample'][ind]]
        writer.writerow(outstring) #write the data
        NeII_NeIII_IR_obj.append(name) #Save the object name in the list NeII_NeIII_IR_obj
    
    elif (Ne_IR_Fq[2] in Fr or Ne_IR_Fq[3] in Fr) and Ne_IR_Fq[4] in Fr:
        print(f"{ind}, {name}, NeII and NeV")
        #Writing the object names
        outstring = [name,df['id_from'][ind],df['RA'][ind],df['DEC'][ind],df['otype_txt'][ind],df['redshift'][ind],
                     df['rvz_type'][ind],df['otypes'][ind],'NeII|NeV',df['SMB_sample'][ind]]
        writer.writerow(outstring) #write the data
        NeII_NeV_IR_obj.append(name) #Save the object name in the list NeII_NeV_IR_obj
    
    elif (Ne_IR_Fq[0] in Fr or Ne_IR_Fq[1] in Fr) and (Ne_IR_Fq[2] in Fr or Ne_IR_Fq[3] in Fr):
        print(f"{ind}, {name}, NeIII and NeV")
        #Writing the object names
        outstring = [name,df['id_from'][ind],df['RA'][ind],df['DEC'][ind],df['otype_txt'][ind],df['redshift'][ind],
                     df['rvz_type'][ind],df['otypes'][ind],'NeIII|NeV',df['SMB_sample'][ind]]
        writer.writerow(outstring) #write the data
        NeIII_NeV_IR_obj.append(name) #Save the object name in the list NeIII_NeV_IR_obj
    
    elif Ne_IR_Fq[0] in Fr or Ne_IR_Fq[1] in Fr:
        print(f"{ind}, {name}, NeIII")
        #Writing the object names
        outstring = [name,df['id_from'][ind],df['RA'][ind],df['DEC'][ind],df['otype_txt'][ind],df['redshift'][ind],
                     df['rvz_type'][ind],df['otypes'][ind],'NeIII',df['SMB_sample'][ind]]
        writer.writerow(outstring) #write the data
        NeIII_IR_obj.append(name) #Save the object name in the list NeIII_IR_obj
    
    elif Ne_IR_Fq[2] in Fr or Ne_IR_Fq[3] in Fr:
        print(f"{ind}, {name}, NeV")
        #Writing the object names
        outstring = [name,df['id_from'][ind],df['RA'][ind],df['DEC'][ind],df['otype_txt'][ind],df['redshift'][ind],
                     df['rvz_type'][ind],df['otypes'][ind],'NeV',df['SMB_sample'][ind]]
        writer.writerow(outstring) #write the data
        NeV_IR_obj.append(name) #Save the object name in the list NeV_IR_obj
   
    elif Ne_IR_Fq[4] in Fr:
        print(f"{ind}, {name}, NeII")
        #Writing the object names
        outstring = [name,df['id_from'][ind],df['RA'][ind],df['DEC'][ind],df['otype_txt'][ind],df['redshift'][ind],
                     df['rvz_type'][ind],df['otypes'][ind],'NeII',df['SMB_sample'][ind]]
        writer.writerow(outstring) #write the data
        NeII_IR_obj.append(name) #Save the object name in the list NeII_IR_obj

end = time.time()

#we close the file with objects names
outfile.close()

print('\nTotal objects found with NeII, NeIII and NeV emission lines: ',len(NeII_NeIII_NeV_IR_obj))
print('Total objects found with NeII and NeIII emission lines: ',len(NeII_NeIII_IR_obj))
print('Total objects found with NeII and NeV emission lines: ',len(NeII_NeV_IR_obj))
print('Total objects found with NeIII and NeV emission lines: ',len(NeIII_NeV_IR_obj))
print('Total objects found with NeIII emission lines: ',len(NeIII_IR_obj))
print('Total objects found with NeV emission lines: ',len(NeV_IR_obj))
print('Total objects found with NeII emission lines: ',len(NeII_IR_obj))
print('\nExecution Time(seg): ' + str(end - start))
print('Execution Time(min): ' + str((end - start)/60))
print('Execution Time(hrs): ' + str((end - start)/3600))
# Out:
# 0, LEDA  165630, NeII, NeIII and NeV
# 1, ESO 362-18, NeII, NeIII and NeV
# 2, 3C 334, NeII, NeIII and NeV
# 3, ESO 323-77, NeII, NeIII and NeV
# 4, NGC  7479, NeII, NeIII and NeV
# 5, M  81, NeII, NeIII and NeV
# 6, NGC  1241, NeII, NeIII and NeV
# 7, NGC  3516, NeII, NeIII and NeV
# 8, IRAS 15206+3342, NeII, NeIII and NeV
# 9, LEDA 1487448, NeII, NeIII and NeV
# 10, Mrk  937, NeII
# 11, ESO 297-18, NeII
# 12, IC  450, NeII, NeIII and NeV
# 13, Mrk  622, NeII, NeIII and NeV
# 14, WISEA J035734.06-053719.6, NeIII
# 15, 2MASS J21035875-0728025, NeIII
# 16, IRAS 15480-0344, NeII, NeIII and NeV
# 17, Mrk  471, NeII, NeIII and NeV
# 18, 2MASS J00105486+0014510, NeIII
# 19, WISEA J005439.78+155447.2, NeIII
# 20, LEDA  166692, NeII, NeIII and NeV
# 21, NGC  4992, NeII
# 22, 3C 295, NeII
# 23, LEDA    3237, NeII
# 24, Mrk  478, NeII, NeIII and NeV
# 25, NGC  1125, NeII and NeIII
# 26, Mrk  279, NeII, NeIII and NeV
# 27, Mrk 1502, NeII, NeIII and NeV
# 28, PB  3894, NeII, NeIII and NeV
# 29, 3C 098, NeV
# 30, NGC  2992, NeII, NeIII and NeV
# 31, NGC  2110, NeII, NeIII and NeV
# 32, UGC  3351, NeII, NeIII and NeV
# 33, NGC   788, NeII, NeIII and NeV
# 34, NGC  4235, NeII, NeIII and NeV
# 35, NGC  6860, NeII, NeIII and NeV
# 36, Mrk  520, NeII
# 37, MCG+04-48-002, NeII, NeIII and NeV
# 38, ICRF J145907.5+714019, NeII, NeIII and NeV
# 39, 2E  2503, NeII, NeIII and NeV
# 40, MCG+00-29-023, NeII, NeIII and NeV
# 41, Z 218-7, NeII, NeIII and NeV
# 42, Mrk  463E, NeII, NeIII and NeV
# 43, LEDA   27453, NeIII
# 44, IRAS 07598+6508, NeII
# 45, NGC  4151, NeII, NeIII and NeV
# 46, NGC  1365, NeII, NeIII and NeV
# 47, 2XMM J101756.8+390526, NeV
# 48, 3C  84, NeII, NeIII and NeV
# 49, ESO 141-55, NeII, NeIII and NeV
# 50, MCG+10-17-021, NeII, NeIII and NeV
# 51, Mrk  509, NeII, NeIII and NeV
# 52, NGC  7591, NeII, NeIII and NeV
# 53, Mrk  493, NeII, NeIII and NeV
# 54, Mrk 1239, NeII, NeIII and NeV
# 55, Mrk  231, NeII, NeIII and NeV
# 56, NGC  3079, NeII, NeIII and NeV
# 57, NGC  4355, NeII
# 58, IRAS 13342+3932, NeII, NeIII and NeV
# 59, WISEA J165939.77+183436.7, NeII, NeIII and NeV
# 60, Mrk  876, NeII, NeIII and NeV
# 61, MCG+13-07-002, NeII, NeIII and NeV
# 62, NGC   253, NeII, NeIII and NeV
# 63, 3C 286, NeII, NeIII and NeV
# 64, NGC  3982, NeII, NeIII and NeV
# 65, ICRF J182931.7+484446, NeII, NeIII and NeV
# 66, ESO 428-14, NeII, NeIII and NeV
# 67, NGC  5728, NeII, NeIII and NeV
# 68, 2MASX J00535615-7038045, NeII, NeIII and NeV
# 69, UGC  1841, NeV
# 70, LEDA    1790, NeII, NeIII and NeV
# 71, Ton  951, NeV
# 72, NGC  4748, NeII, NeIII and NeV
# 73, FAIRALL 0049, NeII, NeIII and NeV
# 74, NGC  3281, NeII, NeIII and NeV
# 75, NGC  5995, NeII, NeIII and NeV
# 76, WISEA J130005.34+163214.8, NeII, NeIII and NeV
# 77, 2MASX J18334627+4727027, NeII, NeIII and NeV
# 78, 2E   437, NeII
# 79, Mrk  877, NeII and NeV
# 80, 3C 033, NeII, NeIII and NeV
# 81, NGC  3393, NeIII and NeV
# 82, IC 1816, NeII, NeIII and NeV
# 83, Mrk 1506, NeII, NeIII and NeV
# 84, Mrk 1014, NeII, NeIII and NeV
# 85, Mrk  771, NeII, NeIII and NeV
# 86, Mrk  304, NeII, NeIII and NeV
# 87, Mrk 1513, NeII, NeIII and NeV
# 88, 2MASS J14294306+4747262, NeII
# 89, 2MASX J10181928+3722419, NeII, NeIII and NeV
# 90, 2MASX J14323249+3406257, NeII and NeIII
# 91, Mrk 1383, NeII, NeIII and NeV
# 92, SDSS J040208.86-050642.0, NeIII
# 93, 3C 452, NeII, NeIII and NeV
# 94, MCG-03-34-064, NeII, NeIII and NeV
# 95, ESO 434-40, NeII, NeIII and NeV
# 96, 4C 13.41, NeII and NeV
# 97, NGC  4593, NeII, NeIII and NeV
# 98, NGC   931, NeII, NeIII and NeV
# 99, 2MASX J21564950-0745325, NeV
# 100, 2MASS J13234951+6541480, NeII
# 101, IC 3078, NeIII
# 102, LEDA   29208, NeII and NeV
# 103, ICRF J134733.3+121724, NeII, NeIII and NeV
# 104, NGC  7743, NeII, NeIII and NeV
# 105, LEDA   90429, NeII, NeIII and NeV
# 106, LEDA   70560, NeII, NeIII and NeV
# 107, LEDA   52314, NeII and NeV
# 108, M  94, NeII, NeIII and NeV
# 109, ESO 323-32, NeII
# 110, Mrk  463, NeV
# 111, NGC  4388, NeII, NeIII and NeV
# 112, M  88, NeII, NeIII and NeV
# 113, NGC  5033, NeII, NeIII and NeV
# 114, ESO  33-2, NeII, NeIII and NeV
# 115, LEDA   90054, NeV
# 116, WISEA J124819.76+662142.6, NeIII
# 117, Mrk  334, NeII, NeIII and NeV
# 118, Mrk  273, NeII, NeIII and NeV
# 119, 2MASX J08584172+1041223, NeII, NeIII and NeV
# 120, 2MASSI J0918486+211717, NeII, NeIII and NeV
# 121, ESO 420-13, NeII and NeV
# 122, IRAS F08216+3009, NeII, NeIII and NeV
# 123, Mrk  817, NeII, NeIII and NeV
# 124, ICRF J130533.0-103319, NeII, NeIII and NeV
# 125, NGC   612, NeII
# 126, NGC  1058, NeII and NeV
# 127, 4C 23.43, NeII, NeIII and NeV
# 128, NGC  6890, NeII, NeIII and NeV
# 129, NGC  2622, NeII, NeIII and NeV
# 130, IC 4518A, NeII, NeIII and NeV
# 131, PG 0953+414, NeII and NeV
# 132, Ton  1565, NeII and NeV
# 133, Ton  1388, NeII and NeV
# 134, 2MASS J14025120+2631175, NeII, NeIII and NeV
# 135, IRAS 17002+5153, NeII and NeV
# 136, IRAS 15091-2107, NeII, NeIII and NeV
# 137, ESO  12-21, NeII, NeIII and NeV
# 138, UGC 12138, NeII, NeIII and NeV
# 139, LEDA   75476, NeII, NeIII and NeV
# 140, SDSS J231812.99-004126.1, NeIII
# 141, Mrk    9, NeII, NeIII and NeV
# 142, NGC  5135, NeII, NeIII and NeV
# 143, ESO 140-43, NeII, NeIII and NeV
# 144, NGC  7410, NeII and NeV
# 145, ESO 198-24, NeII
# 146, IC 1065, NeII, NeIII and NeV
# 147, Mrk  335, NeII, NeIII and NeV
# 148, NGC   513, NeII, NeIII and NeV
# 149, NGC  1204, NeII, NeIII and NeV
# 150, ESO 383-35, NeII, NeIII and NeV
# 151, Mrk  618, NeII, NeIII and NeV
# 152, Mrk  863, NeIII
# 153, NGC  7682, NeII, NeIII and NeV
# 154, NGC  1320, NeII, NeIII and NeV
# 155, UGC  3601, NeII, NeIII and NeV
# 156, NGC  1667, NeII, NeIII and NeV
# 157, M  84, NeV
# 158, NGC  4074, NeII
# 159, LEDA 1365424, NeII, NeIII and NeV
# 160, NGC  3735, NeII, NeIII and NeV
# 161, MCG-01-24-012, NeII, NeIII and NeV
# 162, ICRF J015002.6-072548, NeII, NeIII and NeV
# 163, NGC  2639, NeII, NeIII and NeV
# 164, Mrk 1457, NeII, NeIII and NeV
# 165, Mrk  841, NeII, NeIII and NeV
# 166, NGC  5990, NeII, NeIII and NeV
# 167, ESO 445-50, NeII, NeIII and NeV
# 168, Mrk 1298, NeII and NeV
# 169, Mrk 1095, NeII, NeIII and NeV
# 170, M  49, NeV
# 171, Z 121-75, NeII, NeIII and NeV
# 172, IRAS 04385-0828, NeII, NeIII and NeV
# 173, NGC  4253, NeII, NeIII and NeV
# 174, NGC  4602, NeII and NeV
# 175, NGC   185, NeV
# 176, NGC  2685, NeV
# 177, NGC  3081, NeII, NeIII and NeV
# 178, NGC  2273, NeII, NeIII and NeV
# 179, NGC  4051, NeII, NeIII and NeV
# 180, NGC  6221, NeII, NeIII and NeV
# 181, NGC  4725, NeII, NeIII and NeV
# 182, NGC  7172, NeII, NeIII and NeV
# 183, NGC  6814, NeII, NeIII and NeV
# 184, Mrk  705, NeII, NeIII and NeV
# 185, ESO 263-13, NeII
# 186, NGC  3998, NeII, NeIII and NeV
# 187, NGC  4941, NeII, NeIII and NeV
# 188, NGC  4395, NeII, NeIII and NeV
# 189, 3C 459, NeII, NeIII and NeV
# 190, LEDA   68751, NeII, NeIII and NeV
# 191, NGC  6300, NeII, NeIII and NeV
# 192, ESO 103-35, NeII, NeIII and NeV
# 193, Mrk   79, NeII, NeIII and NeV
# 194, Mrk  573, NeII, NeIII and NeV
# 195, NGC  5548, NeII, NeIII and NeV
# 196, IC  486, NeII, NeIII and NeV
# 197, IC 2560, NeII, NeIII and NeV
# 198, NGC   424, NeII, NeIII and NeV
# 199, LEDA   89032, NeII, NeIII and NeV
# 200, NGC  6240, NeII, NeIII and NeV
# 201, NGC   262, NeII, NeIII and NeV
# 202, NGC  7679, NeII, NeIII and NeV
# 203, NGC  7592, NeV
# 204, IC 5298, NeV
# 205, NGC  4507, NeII, NeIII and NeV
# 206, NGC  4477, NeII, NeIII and NeV
# 207, UGC  6728, NeII, NeIII and NeV
# 208, NGC  7319, NeIII and NeV
# 209, ESO   5-4, NeII, NeIII and NeV
# 210, NGC  6951, NeII, NeIII and NeV
# 211, NGC  1142, NeII, NeIII and NeV
# 212, ESO 253-3, NeII, NeIII and NeV
# 213, Mrk 1073, NeII, NeIII and NeV
# 214, M 106, NeII, NeIII and NeV
# 215, NGC  5252, NeII
# 216, ESO 339-11, NeV
# 217, UGC 12282, NeII, NeIII and NeV
# 218, LEDA   90196, NeII, NeIII and NeV
# 219, NGC  4945, NeII, NeIII and NeV
# 220, NGC  3976, NeII, NeIII and NeV
# 221, NGC  5273, NeII, NeIII and NeV
# 222, NGC  5899, NeII, NeIII and NeV
# 223, NGC  4939, NeII, NeIII and NeV
# 224, NGC    34, NeII, NeIII and NeV
# 225, NGC  7674, NeII, NeIII and NeV
# 226, UGC  5101, NeII, NeIII and NeV
# 227, UGC  7064, NeII and NeIII
# 228, NGC  7469, NeII, NeIII and NeV
# 229, MCG-02-08-039, NeII, NeIII and NeV
# 230, ESO 417-6, NeII, NeIII and NeV
# 231, NGC  1194, NeII, NeIII and NeV
# 232, Mrk    3, NeII, NeIII and NeV
# 233, IC 4553, NeII, NeIII and NeV
# 234, IC 5063, NeII, NeIII and NeV
# 235, 3C 196, NeII, NeIII and NeV
# 236, NGC  1808, NeII, NeIII and NeV
# 237, ESO 113-45, NeII, NeIII and NeV
# 238, NGC  3783, NeII, NeIII and NeV
# 239, NGC  7314, NeII, NeIII and NeV
# 240, ICRF J054236.1+495107, NeII, NeIII and NeV
# 241, Mrk  352, NeII, NeIII and NeV
# 242, 3C  22.0, NeII, NeIII and NeV
# 243, LEDA  165618, NeII, NeIII and NeV
# 244, IRAS 11119+3257, NeII, NeIII and NeV
# 245, 2MASS J15011320+2329082, NeII and NeV
# 246, NGC  3367, NeV
# 247, NGC  4968, NeII, NeIII and NeV
# 248, NGC   660, NeII, NeIII and NeV
# 249, Z  41-20, NeII
# 250, M  58, NeII, NeIII and NeV
# 251, NGC  6926, NeV
# 252, NGC   973, NeII, NeIII and NeV
# 253, NGC  4138, NeII, NeIII and NeV
# 254, NGC  5395, NeV
# 255, NGC  7603, NeII, NeIII and NeV
# 256, NGC  7213, NeII, NeIII and NeV
# 257, UGC  1395, NeII, NeIII and NeV
# 258, NGC   863, NeII, NeIII and NeV
# 259, 2MASS J08105865+7602424, NeII, NeIII and NeV
# 260, ICRF J052109.8+163822, NeII, NeIII and NeV
# 261, PG 0947+396, NeII
# 262, ESO 121-28, NeII
# 263, Ton  182, NeII
# 264, 2MASX J14510879+2709272, NeII and NeV
# 265, NGC  1566, NeII, NeIII and NeV
# 266, Mrk  704, NeII, NeIII and NeV
# 267, 7C 1821+6419, NeII, NeIII and NeV
# 268, NGC  4922, NeII, NeIII and NeV
# 269, WISEA J151653.23+190048.3, NeII, NeIII and NeV
# 270, IC 3639, NeII, NeIII and NeV
# 271, Mrk  609, NeII, NeIII and NeV
# 272, ESO 602-25, NeII, NeIII and NeV
# 273, NGC  1358, NeII, NeIII and NeV
# 274, NGC  3147, NeII, NeIII and NeV
# 275, NGC  1056, NeII, NeIII and NeV
# 276, ESO 511-30, NeII
# 277, SDSS J032845.99+011150.8, NeIII
# 278, NGC  5643, NeII, NeIII and NeV
# 279, SHOC 198, NeIII
# 280, 3C 343.1, NeII, NeIII and NeV
# 281, SBS 1626+554, NeII, NeIII and NeV
# 282, 2MASX J08035923+2345201, NeII, NeIII and NeV
# 283, NGC  3660, NeII, NeIII and NeV
# 284, LEDA   24384, NeII and NeIII
# 285, LEDA 2816291, NeIII
# 286, WISEA J135356.02+664800.5, NeIII
# 287, SDSS J143417.15+020742.3, NeIII
# 288, 2MASX J22041914+0333511, NeII, NeIII and NeV
# 289, SWIFT J0624.1-6059, NeII
# 290, WISEA J114540.46-182714.8, NeII
# 291, Mrk  926, NeII, NeIII and NeV
# 292, WISEA J000703.61+155423.7, NeII, NeIII and NeV
# 293, PG 1048+342, NeII
# 294, LEDA   45656, NeII and NeV
# 295, LEDA  101275, NeII, NeIII and NeV
# 296, 2MASX J14254352+3345275, NeII and NeIII
# 297, 2MASX J14304627+3513133, NeII and NeIII
# 298, 2MASX J14305363+3458364, NeII
# 299, 2MASS J16370022+2221140, NeII, NeIII and NeV
# 300, 2XMM J094046.2+033929, NeV
# 301, 2MASS J10520202+5633010, NeII and NeIII
# 302, 2XMM J094506.4+035552, NeV
# 303, 2MASX J10032788+5541535, NeV
# 304, 2XMM J115657.8+550820, NeV
# 305, 2MASS J10272497+1219196, NeII, NeIII and NeV
# 306, [LGE2006] 12, NeIII
# 307, NGC  5347, NeII, NeIII and NeV
# 308, MCG-03-58-007, NeII, NeIII and NeV
# 309, 2MASX J12390630-1610472, NeII
# 310, IRAS 11215-2806, NeII, NeIII and NeV
# 311, Mrk  883, NeII and NeIII
# 312, IRAS F00183-7111, NeII, NeIII and NeV
# 313, LEDA   37102, NeII, NeIII and NeV
# 314, 2MASX J00215355-7910077, NeII, NeIII and NeV
# 315, SDSS J120424.54+192509.7, NeII, NeIII and NeV
# 316, 2MASS J10434845+5811477, NeII and NeIII
# 317, 2XMM J142930.6+425148, NeV
# 318, SDSS J161647.32+371621.2, NeII, NeIII and NeV
# 319, IRAS 03450+0055, NeII, NeIII and NeV
# 320, WISEA J145331.51+135358.6, NeII, NeIII and NeV
# 321, 3C 265.0, NeII, NeIII and NeV
# 322, LEDA   50824, NeII, NeIII and NeV
# 323, LEDA 2817285, NeII, NeIII and NeV
# 324, NGC  6810, NeII, NeIII and NeV
# 325, ICRF J090933.4+425346, NeII, NeIII and NeV
# 326, ESO 209-12, NeII
# 327, LEDA   17155, NeII, NeIII and NeV
# 328, ESO 506-27, NeII
# 329, LEDA  178130, NeII
# 330, WISEA J183835.40+355220.1, NeII, NeIII and NeV
# 331, WISEA J134133.37-002432.1, NeV
# 332, 3C 343, NeII, NeIII and NeV
# 333, LEDA 3095998, NeII
# 334, Mrk   22, NeII and NeIII
# 335, Mrk 1066, NeII, NeIII and NeV
# 336, 2XMM J135315.8+634546, NeII, NeIII and NeV
# 337, 2E  2389, NeII and NeV
# 338, WISEA J010835.15+214818.5, NeII, NeIII and NeV
# 339, 3C 234.0, NeII, NeIII and NeV
# 340, WISEA J105144.24+353930.7, NeII, NeIII and NeV
# 341, 2MASX J12135486+0247529, NeV
# 342, LEDA   90127, NeII, NeIII and NeV
# 343, MCG+00-25-010, NeII and NeIII
# 344, UGC 11680, NeII
# 345, WISEA J222554.26+195836.9, NeII, NeIII and NeV
# 346, ESO 148-2, NeII, NeIII and NeV
#
# Total objects found with NeII, NeIII and NeV emission lines:  245
# Total objects found with NeII and NeIII emission lines:  11
# Total objects found with NeII and NeV emission lines:  17
# Total objects found with NeIII and NeV emission lines:  2
# Total objects found with NeIII emission lines:  16
# Total objects found with NeV emission lines:  24
# Total objects found with NeII emission lines:  32
#
# Execution Time(seg): 19.178001880645752
# Execution Time(min): 0.3196333646774292
# Execution Time(hrs): 0.00532722274462382

# %%
df2 = pd.read_csv(path+'Obj_Ne-IR_v2_Oct_16_2021.csv')
df2
# Out:
#                        Name_Id id_from          RA        DEC otype_txt  \
# 0                 LEDA  165630  SIMBAD  212.380237   5.192031       Sy2
# 1                   ESO 362-18  SIMBAD   79.899218 -32.657757       Sy2
# 2                       3C 334     NED  245.090910  17.606654       Sy1
# 3                   ESO 323-77  SIMBAD  196.608839 -40.414609       Sy2
# 4                    NGC  7479  SIMBAD  346.236117  12.322878       Sy2
# ..                         ...     ...         ...        ...       ...
# 342               LEDA   90127  SIMBAD  160.121518  10.888390       Sy1
# 343              MCG+00-25-010  SIMBAD  146.007826  -0.642225       Sy1
# 344                  UGC 11680  SIMBAD  316.933750   3.875278       Sy2
# 345  WISEA J222554.26+195836.9     NED  336.475983  19.977017       Sy2
# 346                  ESO 148-2  SIMBAD  348.944883 -59.054428       Sy2
#
#                  redshift rvz_type  \
# 0                  0.2644        z
# 1    0.012582037670874296        c
# 2                 0.55517        z
# 3                0.014904        z
# 4                0.007935        z
# ..                    ...      ...
# 342               0.13635        z
# 343               0.00502        z
# 344                 0.026        z
# 345                 0.147        z
# 346                 0.045        z
#
#                                               otypes      Ne_IR_info  \
# 0                                IR |QSO|Sy2|G  |G    NeII|NeIII|NeV
# 1            Sy2|Sy1|Sy1|G  |Rad|Sy1|AGN|X  |IR |G    NeII|NeIII|NeV
# 2    QSO|QSO|QSO|*  |Rad|IR |QSO|Sy1|Rad|X  |G  |BH?  NeII|NeIII|NeV
# 3        G  |gam|Sy2|Sy1|G  |GiC|AGN|X  |IR |G  |GiG  NeII|NeIII|NeV
# 4                X  |HI |Sy2|G  |Sy2|AGN|Rad|IR |G    NeII|NeIII|NeV
# ..                                               ...             ...
# 342              Rad|AGN|Sy1|LIN|rG |rG |IR |LIN|G    NeII|NeIII|NeV
# 343              EmG|G  |*  |Sy1|GiP|AGN|IR |G  |H2G      NeII|NeIII
# 344                          Sy2|IR |IG |GiP|G  |PaG            NeII
# 345                                  Sy2|AGN|IR |G    NeII|NeIII|NeV
# 346              Rad|G? |G  |AGN|Sy2|AGN|IR |X  |G    NeII|NeIII|NeV
#
#      SMB_sample
# 0             0
# 1            23
# 2           100
# 3           182
# 4           341
# ..          ...
# 342       42459
# 343       42638
# 344       42770
# 345       42772
# 346       43648
#
# [347 rows x 10 columns]

# %% [markdown]
# ### Watermark

# %%
# %load_ext watermark
# %watermark -a "Jonhatan Bernal" -d -v -m
print('Specific Python packages')
# %watermark -iv -w --packages astropy
# Out:
# Author: Jonhatan Bernal
#
# Python implementation: CPython
# Python version       : 3.8.8
# IPython version      : 7.27.0
#
# Compiler    : MSC v.1928 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : AMD64 Family 21 Model 2 Stepping 0, AuthenticAMD
# CPU cores   : 8
# Architecture: 64bit
#
# Specific Python packages
# astropy: 4.3.1
#
# pyvo   : 1.1
# csv    : 1.0
# numpy  : 1.20.3
# pandas : 1.3.3
# astropy: 4.3.1
#
# Watermark: 2.2.0
